# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from preprocess_no_eth_ip_classification import process_df
model=IsolationForest(n_estimators=100, n_jobs=-1, max_samples='auto',contamination=float(0.04), verbose = 0)

# %%
attack_df = pd.read_csv('../data/attack1.csv')
processed_attack = process_df(attack_df)

# %%
normal_df = pd.read_csv('../data/normal1.csv')
processed_normal = process_df(normal_df)

# %%
model.fit(processed_normal.values)
predictions = model.predict(processed_attack.values)

# %%
hi = predictions.tolist()

# %%
from collections import Counter

a = Counter(hi)

# %%
a
# Out:
# Counter({1: 1020184, -1: 50370})

# %%
anomalies = np.where(predictions == -1)

# %%
anomaly_data = attack_df.iloc[anomalies]

# %%
nmap_stuff = anomaly_data[anomaly_data['ip.dst']=='89.100.107.148']

# %%
nmap_stuff
# Out:
#          length     timestamp            eth.src            eth.dst  eth.type  \
# 1214         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1319         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1322         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1498         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1555         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# ...         ...           ...                ...                ...       ...
# 1061736      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061751     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061752      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061764     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061765      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
#
# ...

# %%
processed_normal.columns
# Out:
# Index(['octet_1_ip_src', 'octet_2_ip_src', 'octet_3_ip_src', 'octet_4_ip_src',
#        'octet_1_ip_dst', 'octet_2_ip_dst', 'octet_3_ip_dst', 'octet_4_ip_dst',
#        'length', 'protocol.sport', 'protocol.dport', 'source_pod',
#        'source_external', 'destination_pod', 'destination_external', 'TCP',
#        'UDP', 'packet_flow'],
#       dtype='object')

# %%
model2=IsolationForest(n_estimators=100, n_jobs=-1, max_samples='auto',contamination=float(0.04), verbose = 0)

# %%
model2.fit(processed_normal.values)
# Out:
# IsolationForest(contamination=0.04, n_jobs=-1)

# %%
b = model2.predict(processed_attack.values)

# %%
ano = np.where(b == -1)

# %%
ano
# Out:
# (array([     43,      44,      45, ..., 1070549, 1070551, 1070553]),)

# %%
ano_df = attack_df.iloc[ano]

# %%
nmap2 = ano_df[ano_df['ip.dst']=='89.100.107.148']

# %%
ano_df
# Out:
#          length     timestamp            eth.src            eth.dst  eth.type  \
# 43          132  1.647534e+09  a2:22:62:00:c9:26  ba:c6:5f:04:4f:62      2048
# 44          132  1.647534e+09  a2:22:62:00:c9:26  ba:c6:5f:04:4f:62      2048
# 45          233  1.647534e+09  ba:c6:5f:04:4f:62  a2:22:62:00:c9:26      2048
# 48          233  1.647534e+09  ba:c6:5f:04:4f:62  a2:22:62:00:c9:26      2048
# 50           66  1.647534e+09  ba:c6:5f:04:4f:62  16:30:0c:42:37:39      2048
# ...         ...           ...                ...                ...       ...
# 1070544     270  1.647534e+09  ba:c6:5f:04:4f:62  3a:e0:26:66:ba:06      2048
# 1070545     233  1.647534e+09  ba:c6:5f:04:4f:62  3a:e0:26:66:ba:06      2048
# 1070549     233  1.647534e+09  ba:c6:5f:04:4f:62  3a:e0:26:66:ba:06      2048
# 1070551      66  1.647534e+09  ba:c6:5f:04:4f:62  16:30:0c:42:37:39      2048
# 1070553     571  1.647534e+09  16:30:0c:42:37:39  ba:c6:5f:04:4f:62      2048
#
# ...

# %%
nmap2
# Out:
#          length     timestamp            eth.src            eth.dst  eth.type  \
# 1214         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1319         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1322         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1498         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1555         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# ...         ...           ...                ...                ...       ...
# 1061736      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061751     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061752      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061764     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061765      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
#
# ...

# %%
ano_df['ip.dst'].value_counts()
# Out:
# 89.100.107.148     41824
# 20.126.199.164      1907
# 168.63.129.16       1657
# 89.100.107.147      1641
# 10.244.0.11         1568
# 10.244.0.7          1309
# 10.244.0.2          1173
# 10.244.0.10          627
# 10.244.0.4           513
# 10.244.0.9           450
# 13.69.65.31          253
# 10.244.0.15          248
# 13.69.65.29          231
# 13.69.65.27          219
# 13.69.67.61          175
# 10.244.0.3           154
# 40.113.176.128       149
# 20.50.65.82           61
# 142.250.179.138       57
# 66.249.83.16          55
# 66.249.83.12          51
# 198.143.164.251       38
# 13.69.114.0           36
# 66.249.81.204         35
# 10.244.0.6            35
# 99.84.11.20           33
# 151.139.128.11        25
# 198.143.164.243       24
# 99.84.11.83           23
# 10.244.0.5            19
# 13.69.106.217         16
# 13.69.106.216         13
# 13.69.106.211         13
# 99.84.11.57           11
# 13.69.106.89           9
# 13.69.106.212          9
# 172.217.168.234        9
# ...

# %%
anomaly_data.shape
# Out:
# (53639, 56)

# %%
model3=IsolationForest(n_estimators=100, n_jobs=-1, max_samples='auto',contamination=float(0.04), verbose = 0)

# %%
pred_3 = model3.fit_predict(processed_attack.values)

# %%
pred_3
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
yada = pred_3.tolist()

# %%
Counter(yada)
# Out:
# Counter({-1: 42723, 1: 1027831})

# %%
anomalies_np = np.where(pred_3 == -1)

# %%
anomaly3df = attack_df.iloc[anomalies_np]

# %%
anomaly3df
# Out:
#          length     timestamp            eth.src            eth.dst  eth.type  \
# 0           180  1.647534e+09  ba:c6:5f:04:4f:62  36:b6:5a:50:8a:98      2048
# 1           310  1.647534e+09  36:b6:5a:50:8a:98  ba:c6:5f:04:4f:62      2048
# 2           198  1.647534e+09  ba:c6:5f:04:4f:62  36:b6:5a:50:8a:98      2048
# 3            66  1.647534e+09  36:b6:5a:50:8a:98  ba:c6:5f:04:4f:62      2048
# 37          121  1.647534e+09  16:30:0c:42:37:39  a2:22:62:00:c9:26      2048
# ...         ...           ...                ...                ...       ...
# 1070548      74  1.647534e+09  16:30:0c:42:37:39  ba:c6:5f:04:4f:62      2048
# 1070549     233  1.647534e+09  ba:c6:5f:04:4f:62  3a:e0:26:66:ba:06      2048
# 1070551      66  1.647534e+09  ba:c6:5f:04:4f:62  16:30:0c:42:37:39      2048
# 1070552      54  1.647534e+09  16:30:0c:42:37:39  ba:c6:5f:04:4f:62      2048
# 1070553     571  1.647534e+09  16:30:0c:42:37:39  ba:c6:5f:04:4f:62      2048
#
# ...

# %%
nmap3 = anomaly3df[anomaly3df['ip.dst']=='89.100.107.148']

# %%
nmap3
# Out:
#          length     timestamp            eth.src            eth.dst  eth.type  \
# 1214         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1319         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1322         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1498         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1555         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# ...         ...           ...                ...                ...       ...
# 1061715     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061720     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061735     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061751     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061764     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
#
# ...
