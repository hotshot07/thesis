# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from preprocess_no_eth_ip_classification import process_df
model=IsolationForest(n_estimators=100, n_jobs=-1, max_samples='auto', contamination = 'auto',verbose = 0)

# %%
attack_df = pd.read_csv('../data/attack1.csv')
processed_attack = process_df(attack_df)

normal_df = pd.read_csv('../data/normal1.csv')
processed_normal = process_df(normal_df)

# %%
model.fit(processed_normal.values)
# Out:
# IsolationForest(n_jobs=-1)

# %%
preds = model.predict(processed_attack.values)

# %%
from collections import Counter

pred_list = preds.tolist()


print(Counter(pred_list))
# Out:
# Counter({1: 862082, -1: 208472})

# %%
anoms = np.where(preds == -1)

anomaly_data = attack_df.iloc[anoms]

# %%
nmap_df = anomaly_data[anomaly_data['ip.dst']=='89.100.107.148']

# %%
nmap_df
# Out:
#          length     timestamp            eth.src            eth.dst  eth.type  \
# 1214         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1319         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1322         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1498         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1555         58  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# ...         ...           ...                ...                ...       ...
# 1061736      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061751     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061752      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061764     581  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061765      66  1.647534e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
#
# ...

# %%
anomaly_data[(anomaly_data['destination_pod']==1) & (anomaly_data['source_pod']==1)]
# Out:
#          length     timestamp            eth.src            eth.dst  eth.type  \
# 5           151  1.647534e+09  16:30:0c:42:37:39  3a:e0:26:66:ba:06      2048
# 6           151  1.647534e+09  ba:c6:5f:04:4f:62  3a:e0:26:66:ba:06      2048
# 7           151  1.647534e+09  16:30:0c:42:37:39  3a:e0:26:66:ba:06      2048
# 8           151  1.647534e+09  ba:c6:5f:04:4f:62  3a:e0:26:66:ba:06      2048
# 9           244  1.647534e+09  3a:e0:26:66:ba:06  16:30:0c:42:37:39      2048
# ...         ...           ...                ...                ...       ...
# 1070540     394  1.647534e+09  3a:e0:26:66:ba:06  16:30:0c:42:37:39      2048
# 1070543     394  1.647534e+09  3a:e0:26:66:ba:06  16:30:0c:42:37:39      2048
# 1070546     283  1.647534e+09  3a:e0:26:66:ba:06  16:30:0c:42:37:39      2048
# 1070547     346  1.647534e+09  3a:e0:26:66:ba:06  16:30:0c:42:37:39      2048
# 1070550     346  1.647534e+09  3a:e0:26:66:ba:06  16:30:0c:42:37:39      2048
#
# ...

# %%
normal_ips = set(normal_df['ip.dst'])
predicted_anomalies_ips = set(anomaly_data['ip.dst'])

# %%
predicted_anomalies_ips.difference(normal_ips)
# Out:
# {'13.69.106.208',
#  '13.69.106.216',
#  '13.69.106.217',
#  '142.250.179.138',
#  '142.250.179.142',
#  '142.251.36.42',
#  '151.139.128.11',
#  '169.254.169.254',
#  '172.217.168.234',
#  '198.143.164.243',
#  '216.58.214.14',
#  '45.83.65.187',
#  '45.83.65.88',
#  '66.249.81.204',
#  '66.249.81.206',
#  '66.249.83.12',
#  '66.249.83.14',
#  '66.249.83.16',
#  '99.84.11.20',
#  '99.84.11.57',
#  '99.84.11.83'}

# %%
normal_ips.difference(predicted_anomalies_ips)
# Out:
# {'13.69.106.88',
#  '172.104.131.24',
#  '192.241.213.181',
#  '198.143.164.252',
#  '198.143.164.254',
#  '23.251.102.74',
#  '52.236.186.216',
#  '52.236.186.217',
#  '66.240.205.34'}

# %%
attack_ips = set(attack_df['ip.dst'])

# %%
predicted_anomalies_ips.difference(attack_ips)
# Out:
# set()

# %%
normal_df[normal_df['ip.dst']=='89.100.107.148']
# Out:
#         length     timestamp            eth.src            eth.dst  eth.type  \
# 93219       74  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 93221       74  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 93225       66  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 93432     2962  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 93433     1163  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# ...        ...           ...                ...                ...       ...
# 140164      66  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 140165      66  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 140166      66  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 140168      66  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 140170      66  1.647532e+09  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
#
# ...

# %%
from final_processing_maybe import process_df

# %%
attack_df = pd.read_csv('../data/attack1.csv')
processed_attack = process_df(attack_df)

normal_df = pd.read_csv('../data/normal1.csv')
processed_normal = process_df(normal_df)

# %%
model2 = IsolationForest(n_estimators=100, n_jobs=-1, max_samples='auto', contamination = 'auto',verbose = 0)

# %%
model.fit(processed_normal.values)
# Out:
# IsolationForest(n_jobs=-1)

# %%
preds2 = model.predict(processed_attack.values)

# %%
from collections import Counter

pred_list2 = preds2.tolist()


print(Counter(pred_list2))
# Out:
# Counter({1: 872753, -1: 197801})

# %%
anoms2 = np.where(preds2 == -1)

anomaly_data2 = attack_df.iloc[anoms2]

# %%
nmap_df2 = anomaly_data2[anomaly_data2['ip.dst']=='89.100.107.148']

# %%
nmap_df2
# Out:
#          length   timestamp            eth.src            eth.dst  eth.type  \
# 1214         58  1647533655  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1319         58  1647533656  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1322         58  1647533656  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1498         58  1647533657  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1555         58  1647533659  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# ...         ...         ...                ...                ...       ...
# 1061736      66  1647534203  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061751     581  1647534203  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061752      66  1647534203  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061764     581  1647534203  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
# 1061765      66  1647534203  6a:77:c0:85:72:c3  ba:c6:5f:04:4f:62      2048
#
# ...

# %%
# Out:
# Index(['octet_1_ip_src', 'octet_2_ip_src', 'octet_3_ip_src', 'octet_4_ip_src',
#        'octet_1_ip_dst', 'octet_2_ip_dst', 'octet_3_ip_dst', 'octet_4_ip_dst',
#        'length', 'protocol.sport', 'protocol.dport', 'source_pod',
#        'source_external', 'destination_pod', 'destination_external', 'TCP',
#        'UDP', 'packet_flow_10_s'],
#       dtype='object')

# %%
anomaly_data['ip.src'].value_counts()
# Out:
# 10.244.0.15        78562
# 10.244.0.14        22265
# 10.244.0.9         19559
# 10.244.0.4         19399
# 10.244.0.7         14887
# 20.126.199.164     11669
# 10.244.0.11         5816
# 10.240.0.4          4538
# 10.244.0.2          3517
# 10.244.0.3          1309
# 168.63.129.16       1219
# 10.244.0.10          737
# 10.244.0.6           548
# 10.244.0.1           468
# 13.69.65.27          356
# 10.244.0.5           296
# 13.69.65.31          293
# 13.69.65.29          265
# 13.69.67.61          229
# 40.113.176.128       118
# 142.250.179.138       55
# 20.50.65.82           53
# 13.69.114.0           51
# 198.143.164.251       34
# 99.84.11.20           29
# 142.251.36.42         28
# 13.69.106.212         26
# 13.69.106.211         24
# 151.139.128.11        23
# 198.143.164.243       22
# 99.84.11.83           21
# 52.236.186.218        19
# 13.69.106.89          19
# 13.69.106.217         18
# 13.69.106.208         12
# 13.69.106.216         12
# 99.84.11.57           10
# ...
