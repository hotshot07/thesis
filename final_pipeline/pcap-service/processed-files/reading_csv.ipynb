# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/hotshot07/Desktop/thesis/final_pipeline/pcap-service/processed-files/pcap-28-03-22-1648425622.csv')

# %%
df
# Out:
#         length     timestamp        ip.src        ip.dst protocol  \
# 0          180  1.648426e+09    10.240.0.4    10.244.0.6      TCP
# 1          310  1.648426e+09    10.244.0.6  20.73.113.93      TCP
# 2           66  1.648426e+09  20.73.113.93    10.244.0.6      TCP
# 3          198  1.648426e+09  20.73.113.93    10.244.0.6      TCP
# 4           66  1.648426e+09    10.244.0.6  20.73.113.93      TCP
# ...        ...           ...           ...           ...      ...
# 358165      66  1.648426e+09    10.244.0.6    10.240.0.4      TCP
# 358166     238  1.648426e+09    10.244.0.6  20.73.113.93      TCP
# 358167     198  1.648426e+09  20.73.113.93    10.244.0.6      TCP
# 358168      66  1.648426e+09    10.244.0.6    10.240.0.4      TCP
# 358169      66  1.648426e+09    10.244.0.6  20.73.113.93      TCP
#
#         protocol.sport  protocol.dport  source_internal  source_external  \
# 0                10250           36032                1                0
# ...
