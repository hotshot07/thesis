# %%
import pandas as pd

# %%
df = pd.read_csv('processed_wordpress1.csv')

# %%
df
# Out:
#                                    uuid     timestamp  length         ip.src  \
# 0      cd3a3440edbf456ca2b2b6abc008734d  1.645211e+09      96     10.240.0.4
# 1      582d01e2622e4b299295f5da53f64fe4  1.645211e+09     172     10.240.0.4
# 2      2abe6186ba7f4408b6669e452328e953  1.645211e+09     230    10.244.0.11
# 3      19de619fed59441f97b04f5880fec907  1.645211e+09      66  52.143.28.136
# 4      ca5709bea49f4cc682df0257a9113fd5  1.645211e+09     198  52.143.28.136
# ...                                 ...           ...     ...            ...
# 42855  dcaabce5b6f9461bb30c394c54b04258  1.645211e+09      66     10.244.0.2
# 42856  5bc5b59441364def8fc976b50b8f3633  1.645211e+09      66     10.244.0.2
# 42857  2399be733fa34141b81e7697fbd804c0  1.645211e+09      66     10.244.0.2
# 42858  c4c489a3dc834ce5ab0b214fa966e517  1.645211e+09      78     10.244.0.6
# 42859  93ac4b81ea4e446eb1151c584a8eefe8  1.645211e+09      66     10.244.0.6
#
# ...

# %%
dummy_protocol = pd.get_dummies(df["protocol"])

# %%
dummy_protocol
# Out:
#    TCP  UDP
# 0    1    0
# 1    0    1
# 2    1    0
# 3    1    0
# 4    0    1
